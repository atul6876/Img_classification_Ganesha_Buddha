# %%
#!pip install requests
#!pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import os
import urllib
import argparse

from imutils import paths
import argparse
import cv2
import requests

# %%
searchterm = 'Ganesh Painting' # will also be the name of the folder
url = "https://www.google.co.in/search?q="+searchterm+"&source=lnms&tbm=isch"
# NEED TO DOWNLOAD CHROMEDRIVER, insert path to chromedriver inside parentheses in following line
browser = webdriver.Chrome('webdriver/chromedriver.exe')
browser.get(url)
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}

urlList = [] 

#if not os.path.exists(searchterm):
#    os.mkdir(searchterm)

for _ in range(500):
    browser.execute_script("window.scrollBy(0,10000)")

for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    #print("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
    urlList.append(json.loads(x.get_attribute('innerHTML'))["ou"])
    
browser.close()
print('Number of URLs tracked: ', len(urlList))

with open(searchterm+'URLs.txt', 'w') as f:
    for item in urlList:
        f.write("%s\n" % item)
# Out:
# Number of URLs tracked:  400

# %%
searchterm = 'Buddha Painting' # will also be the name of the folder
url = "https://www.google.co.in/search?q="+searchterm+"&source=lnms&tbm=isch"
# NEED TO DOWNLOAD CHROMEDRIVER, insert path to chromedriver inside parentheses in following line
browser = webdriver.Chrome('webdriver/chromedriver.exe')
browser.get(url)
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}

urlList = [] 

#if not os.path.exists(searchterm):
#    os.mkdir(searchterm)

for _ in range(500):
    browser.execute_script("window.scrollBy(0,10000)")

for x in browser.find_elements_by_xpath('//div[contains(@class,"rg_meta")]'):
    #print("URL:",json.loads(x.get_attribute('innerHTML'))["ou"])
    urlList.append(json.loads(x.get_attribute('innerHTML'))["ou"])
    
browser.close()
print('Number of URLs tracked: ', len(urlList))

with open(searchterm+'URLs.txt', 'w') as f:
    for item in urlList:
        f.write("%s\n" % item)
# Out:
# Number of URLs tracked:  400

# %%
searchterm = 'Ganesh Painting'

path_text=searchterm+'URLs.txt'

o = open(path_text,"r")
url0 = o.read()
o.close()

## list, containing downloaded files 
urls = url0.split()
print("The number of urls: {}".format(len(urls)))
print('-'*50)
for url in urls[:10]:
    print(url)
    
loc_data = "./data/"+searchterm+"/"
try:
    os.makedirs(loc_data)
except:
    pass
iimage = 0
for url in urls:
    try:
        f = open(loc_data + 'image{:05.0f}.jpg'.format(iimage),'wb')
        f.write(requests.get(url).content)
        f.close()
        iimage += 1
    except Exception as e:
        print("\n{} {}".format(e,url))
        pass
# Out:
# The number of urls: 400
# ____________________________
# https://indiearts.in/wp-content/uploads/2014/07/ganesha-2-MKAG-218X36ACRYLIC-ON-CANVAS1.jpg
# http://full.creative.touchtalent.com/ganesh-painting-501506.jpg
# https://i.imged.com/god-ganesh-painting-handmade-indian-miniature-hindu-religion-old-stamp-paper-art-39865078.jpg
# https://www.upahar.com/image/cache/catalog/handicraft/Pattachitra-Ganesh-Painting-1000x1000.jpg
# https://images.saatchiart.com/saatchi/666791/art/2950806/2020699-VIFXDPWB-7.jpg
# https://4.imimg.com/data4/QL/NM/MY-6467495/1--500x500.jpg
# https://rukminim1.flixcart.com/image/704/704/painting/s/p/k/sa915g6340-1-art-of-creations-original-imaeav9trastkeez.jpeg?q=70
# https://images.fineartamerica.com/images/artworkimages/mediumlarge/1/1-shri-ganesh-sowjanya-sreeram.jpg
# https://ae01.alicdn.com/kf/HTB1eTmfolUSMeJjy1zjq6A0dXXap/Gifted-Artist-Pure-Handmade-Textured-Ganesh-Knife-Oil-Painting-on-Canvas-Abstract-Ganesh-Portrait-Oil-Painting.jpg
# https://images.fineartamerica.com/images-medium-large-5/lord-ganesh-abhishek-purohit.jpg
#
# HTTPSConnectionPool(host='product.shimply.com', port=443): Max retries exceeded with url: /3663/20112173/imfpa-lord-ganesh-painting-small.jpg?1477385421 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001D7FFAF52E8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')) https://product.shimply.com/3663/20112173/imfpa-lord-ganesh-painting-small.jpg?1477385421
#
# HTTPSConnectionPool(host='tatinis.com', port=443): Max retries exceeded with url: /images/detailed/7/Bal_Ganesh.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])"))) https://tatinis.com/images/detailed/7/Bal_Ganesh.jpg

# %%
searchterm = 'Buddha Painting'

path_text=searchterm+'URLs.txt'

o = open(path_text,"r")
url0 = o.read()
o.close()

## list, containing downloaded files 
urls = url0.split()
print("The number of urls: {}".format(len(urls)))
print('-'*50)
for url in urls[:10]:
    print(url)
    
loc_data = "./data/"+searchterm+"/"
try:
    os.makedirs(loc_data)
except:
    pass
iimage = 0
for url in urls:
    try:
        f = open(loc_data + 'image{:05.0f}.jpg'.format(iimage),'wb')
        f.write(requests.get(url).content)
        f.close()
        iimage += 1
    except Exception as e:
        print("\n{} {}".format(e,url))
        pass
# Out:
# The number of urls: 400
# ____________________________
# https://images-na.ssl-images-amazon.com/images/I/51KozxSxwdL.jpg
# https://cdn.shopify.com/s/files/1/1843/4923/products/product-image-435183699_1024x1024.jpg?v=1506596636
# https://rukminim1.flixcart.com/image/832/832/painting/m/y/2/r016141-1218-delight-original-imaef5dtufhadhw8.jpeg?q=70
# https://images.saatchiart.com/saatchi/1009930/art/4053193/3123046-VQMCSNSF-7.jpg
# https://www.sendgift2india.com/image/cache/data/online/Painting/Buddha%20Painting-1200x1200.jpg
# https://images-na.ssl-images-amazon.com/images/I/616I8jeyAnL._SX425_.jpg
# https://5.imimg.com/data5/XL/BU/MY-10701705/buddha-acrylic-painting-500x500.jpg
# https://d3rf6j5nx5r04a.cloudfront.net/FEzPcmmW3zQBqUSZVp-Uj8nZmbg=/558x750/product/f/1/9dd067ffd97b418eb4776938b41a1773_opt.jpg
# https://cdn.bestcollegeart.com/media/catalog/product/cache/1/thumbnail/1000x/17f82f742ffe127f42dca9de82fb58b1/W/a/Way_of_Boddha_1.jpg
# https://i.etsystatic.com/7749621/r/il/9b35c1/852529529/il_794xN.852529529_2pny.jpg
#
# HTTPSConnectionPool(host='www.funkystuff.com.au', port=443): Max retries exceeded with url: /images/thumbs/0065764_beautiful-hand-painted-abstract-buddha-painting-canvascm_560.jpeg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])"))) https://www.funkystuff.com.au/images/thumbs/0065764_beautiful-hand-painted-abstract-buddha-painting-canvascm_560.jpeg

# %%
from keras.preprocessing.image import load_img 
import matplotlib.pyplot as plt

fnames = os.listdir('data/Buddha Painting')
fig = plt.figure(figsize=(10,10))
count = 1
for fnm in fnames[:12]:
    img = load_img('data/Buddha Painting/' +fnm,target_size=(400,400))
    ax = fig.add_subplot(3,4,count)
    count += 1
    ax.imshow(img)
    ax.axis("off")
plt.show()

# %%
fnames = os.listdir('data/Ganesh Painting')
fig = plt.figure(figsize=(10,10))
count = 1
for fnm in fnames[:12]:
    img = load_img('data/Ganesh Painting/'+fnm,target_size=(400,400))
    ax = fig.add_subplot(3,4,count)
    count += 1
    ax.imshow(img)
    ax.axis("off")
plt.show()
